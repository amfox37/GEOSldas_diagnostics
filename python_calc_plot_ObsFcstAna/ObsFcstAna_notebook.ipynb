# %%
import numpy as np
import os
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from netCDF4 import Dataset
import matplotlib.pyplot as plt

from helper.read_GEOSldas import read_tilecoord, read_obs_param
from helper.util import make_folder, array2grid
from helper.plot import plotMap
from helper.smapeasev2 import smapeasev2_ind2latlon
from helper.compute_monthly_stats import compute_monthly_stats
from helper.write_nc4 import write_sums_nc4

import warnings; warnings.filterwarnings("ignore")
import sys 
import io

sys.stdout = io.TextIOWrapper(open(sys.stdout.fileno(), 'wb', 0), write_through=True)
sys.stderr = io.TextIOWrapper(open(sys.stderr.fileno(), 'wb', 0), write_through=True)

# %%
expdir = '/discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/'
expid = 'LS_DAv8_M36'
domain = 'SMAP_EASEv2_M36_GLOBAL'

start_time = datetime(2000,6,1)
end_time = datetime(2024,4,1)

# %%
# Define a minimum threshold for the temporal data points to ensure statistical reliability
# of the computed metrics. 
Nmin = 20

# Base directory for storing monthly files
# This can be the same as the experiment directory (expdir) or a different location
out_path_mo = expdir+expid+'/output/'+domain+'/ana/ens_avg/'

# Directory for diagnostic plots
out_path = expdir+expid+'/output/'+domain+'/figures/'
make_folder(out_path)

# Variable list for computing sum and sum of squared
var_list = ['obs_obs', 'obs_obsvar','obs_fcst','obs_fcstvar','obs_ana','obs_anavar']

# %%
# Read tilecoord and obsparam for tile and obs species information
ftc = expdir+expid+'/output/'+domain+'/rc_out/'+expid+'.ldas_tilecoord.bin'
tc = read_tilecoord(ftc)
n_tile = tc['N_tile']

# fop = expdir+expid+'/output/'+domain+'/rc_out/Y2020/M01/'+expid+'.ldas_obsparam.20200101_0000z.txt'
fop = expdir+expid+'/output/'+domain+'/rc_out/Y2015/M04/'+expid+'.ldas_obsparam.20150401_0000z.txt'
if not os.path.exists(fop):
    raise FileNotFoundError(f"File not found: {fop}")
obs_param = read_obs_param(fop)
n_spec = len(obs_param)

# %%
# Initialize statistical metrics 
data_sum = {}
data2_sum = {}
N_data = np.zeros((n_tile, n_spec))
oxf_sum = np.zeros((n_tile, n_spec))
oxa_sum = np.zeros((n_tile, n_spec))
fxa_sum = np.zeros((n_tile, n_spec))

for var in var_list:
    data_sum[var] = np.zeros((n_tile, n_spec))
    data2_sum[var] = np.zeros((n_tile, n_spec))

# %%
# Time loop: processing data at monthly time step
date_time = start_time
while date_time < end_time:
    # File to store monthly statistics    
    fout_path = out_path_mo + '/Y'+ date_time.strftime('%Y') + '/M' + date_time.strftime('%m') + '/'
    make_folder(fout_path)
    
    fout = fout_path + expid+'.ens_avg.ldas_ObsFcstAna.' + date_time.strftime('%Y%m') +'_stats.nc4'

    # Read monthly data if file exists, otherwise compute monthly statistics first   
    if os.path.isfile(fout):
        print('read sums from  monthly file: '+fout)
        mdata_sum = {}
        mdata2_sum = {}
        with Dataset(fout,'r') as nc:
            mN_data = nc.variables['N_data'][:]
            moxf_sum = nc.variables['obsxfcst_sum'][:]
            moxa_sum = nc.variables['obsxana_sum'][:]
            mfxa_sum = nc.variables['fcstxana_sum'][:]
            for var in var_list:
                mdata_sum[var] = nc.variables[var+'_sum'][:]
                mdata2_sum[var] = nc.variables[var+'2_sum'][:]
    else:
        print('compute monthly sums for '+date_time.strftime('%Y%m'))
        mN_data, mdata_sum, mdata2_sum, moxf_sum, moxa_sum, mfxa_sum = \
                 compute_monthly_stats(expdir,expid,domain,date_time,tc,obs_param,var_list)
        print('save to monthly file: '+fout)
        write_sums_nc4(fout, mN_data,mdata_sum, mdata2_sum, moxf_sum, moxa_sum, mfxa_sum, obs_param)

    # Aggregate monthly data
    N_data += mN_data
    oxf_sum += moxf_sum
    oxa_sum += moxa_sum
    fxa_sum += mfxa_sum
   
    for var in var_list:
        data_sum[var] += mdata_sum[var] 
        data2_sum[var] += mdata2_sum[var]  
        
    date_time =date_time + relativedelta(months=1)
# Out:
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200006_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200007_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200008_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200009_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200010_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200011_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2000/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200012_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200101_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200102_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200103_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200104_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200105_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200106_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200107_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200108_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200109_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200110_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200111_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2001/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200112_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200201_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200202_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200203_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200204_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200205_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200206_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200207_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200208_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200209_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200210_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200211_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2002/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200212_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200301_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200302_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200303_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200304_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200305_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200306_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200307_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200308_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200309_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200310_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200311_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2003/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200312_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200401_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200402_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200403_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200404_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200405_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200406_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200407_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200408_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200409_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200410_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200411_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2004/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200412_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200501_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200502_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200503_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200504_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200505_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200506_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200507_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200508_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200509_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200510_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200511_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2005/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200512_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200601_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200602_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200603_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200604_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200605_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200606_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200607_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200608_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200609_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200610_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200611_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2006/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200612_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200701_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200702_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200703_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200704_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200705_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200706_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200707_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200708_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200709_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200710_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200711_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2007/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200712_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200801_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200802_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200803_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200804_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200805_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200806_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200807_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200808_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200809_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200810_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200811_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2008/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200812_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200901_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200902_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200903_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200904_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200905_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200906_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200907_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200908_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200909_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200910_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200911_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2009/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.200912_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201001_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201002_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201003_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201004_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201005_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201006_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201007_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201008_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201009_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201010_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201011_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2010/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201012_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201101_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201102_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201103_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201104_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201105_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201106_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201107_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201108_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201109_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201110_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201111_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2011/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201112_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201201_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201202_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201203_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201204_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201205_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201206_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201207_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201208_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201209_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201210_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201211_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2012/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201212_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201301_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201302_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201303_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201304_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201305_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201306_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201307_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201308_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201309_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201310_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201311_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2013/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201312_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201401_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201402_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201403_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201404_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201405_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201406_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201407_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201408_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201409_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201410_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201411_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2014/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201412_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201501_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201502_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201503_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201504_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201505_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201506_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201507_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201508_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201509_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201510_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201511_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2015/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201512_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201601_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201602_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201603_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201604_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201605_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201606_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201607_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201608_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201609_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201610_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201611_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2016/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201612_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201701_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201702_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201703_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201704_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201705_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201706_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201707_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201708_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2017/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201709_stats.nc4
# ...
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201807_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201808_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201809_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201810_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201811_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2018/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201812_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201901_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201902_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201903_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201904_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201905_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201906_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201907_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201908_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201909_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201910_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201911_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2019/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.201912_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202001_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202002_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202003_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202004_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202005_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202006_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202007_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202008_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202009_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202010_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202011_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2020/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202012_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202101_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202102_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202103_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202104_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202105_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202106_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202107_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202108_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202109_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202110_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202111_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2021/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202112_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202201_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202202_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202203_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202204_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202205_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202206_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202207_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202208_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202209_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202210_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202211_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2022/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202212_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202301_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202302_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202303_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M04/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202304_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M05/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202305_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M06/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202306_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M07/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202307_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M08/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202308_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M09/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202309_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M10/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202310_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M11/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202311_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2023/M12/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202312_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2024/M01/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202401_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2024/M02/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202402_stats.nc4
# read sums from  monthly file: /discover/nobackup/projects/land_da/Experiment_archive/M21C_land_sweeper_DAv8_M36/LS_DAv8_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg//Y2024/M03/LS_DAv8_M36.ens_avg.ldas_ObsFcstAna.202403_stats.nc4

# %%
species_groups = {
    "SMOS": [0, 1, 2, 3],
    "SMAP": [4, 5, 6, 7],
    "ASCAT": [8, 9, 10],
    "MODIS": [11, 12]
}

# Initialize storage for time series data
N_data_group_all_months = {group: [] for group in species_groups}
OmF_mean_all_months = {group: [] for group in species_groups}
OmF_stdv_all_months = {group: [] for group in species_groups}
monthly_timestamps = []  # To store the timestamps for each month

# Time loop: processing data at monthly time step
date_time = start_time
while date_time < end_time:
    # File to store monthly statistics
    fout_path = out_path_mo + '/Y' + date_time.strftime('%Y') + '/M' + date_time.strftime('%m') + '/'
    make_folder(fout_path)

    fout = fout_path + expid + '.ens_avg.ldas_ObsFcstAna.' + date_time.strftime('%Y%m') + '_stats.nc4'

    # Read monthly data if file exists
    if os.path.isfile(fout):
        print('Reading sums from monthly file: ' + fout)
        with Dataset(fout, 'r') as nc:
            mN_data = nc.variables['N_data'][:]  # Shape: (tiles, species)
            moxf_sum = nc.variables['obsxfcst_sum'][:]  # Shape: (tiles, species)
            mdata_sum = {var: nc.variables[var + '_sum'][:] for var in var_list}
            mdata2_sum = {var: nc.variables[var + '2_sum'][:] for var in var_list}
    else:
        print('Cannot find monthly file: ' + fout)
        date_time += relativedelta(months=1)
        continue

    # Compute metrics for each species group
    for group, indices in species_groups.items():
        # Sum across tiles for the species in this group
        N_data_group = np.sum(mN_data[:, indices], axis=1)  # Total count for the group
        OmF_sum_group = np.sum(moxf_sum[:, indices], axis=1)  # Total OmF sum for the group

        # Convert N_data_group to float to allow NaN values
        N_data_group = N_data_group.astype(float)

        # Filter out invalid data
        N_data_group[N_data_group == 0] = np.nan

        # Compute group-level means and variances
        data_mean = {var: np.sum(mdata_sum[var][:, indices], axis=1) / N_data_group for var in var_list}
        data2_mean = {var: np.sum(mdata2_sum[var][:, indices], axis=1) / N_data_group for var in var_list}
        data_var = {var: data2_mean[var] - data_mean[var]**2 for var in var_list}

        # Compute OmF_mean and OmF_stdv
        OmF_mean = data_mean['obs_obs'] - data_mean['obs_fcst']
        OmF_stdv = np.sqrt(
            data_var['obs_obs'] + data_var['obs_fcst'] -
            2 * (OmF_sum_group / N_data_group - data_mean['obs_obs'] * data_mean['obs_fcst'])
        )

        # Ensure arrays are writable
        OmF_mean = np.copy(OmF_mean)
        OmF_stdv = np.copy(OmF_stdv)

        # Aggregate results to single values
        N_data_group_total = np.nansum(N_data_group)
        OmF_mean_avg = np.nanmean(OmF_mean)
        OmF_stdv_avg = np.nanmean(OmF_stdv)

        # Store the results for the current month
        N_data_group_all_months[group].append(N_data_group_total)
        OmF_mean_all_months[group].append(OmF_mean_avg)
        OmF_stdv_all_months[group].append(OmF_stdv_avg)

    # Store the current timestamp for the month
    monthly_timestamps.append(date_time)

    # Increment to the next month
    date_time += relativedelta(months=1)

# Plot N_data_group for each species group
plt.figure(figsize=(10, 6))
for group, values in N_data_group_all_months.items():
    values_in_millions = [v / 1e6 for v in values]
    plt.plot(monthly_timestamps, values_in_millions, label=group)
plt.gcf().autofmt_xdate()
plt.xlabel('Month')
plt.ylabel('N_data (Millions)')
plt.title('Total N_data by Species Group (in Millions)')
plt.legend()
plt.grid()
plt.show()
plt.close()

# Plot OmF_mean for each species group
for group, values in OmF_mean_all_months.items():
    plt.figure(figsize=(10, 6))
    plt.plot(monthly_timestamps, values, label=f'{group} OmF Mean', color='blue')
    plt.gcf().autofmt_xdate()
    plt.xlabel('Month')
    plt.ylabel('OmF Mean')
    plt.title(f'OmF Mean for {group}')
    plt.legend()
    plt.grid()
    plt.savefig(out_path + f'OmF_Mean_{group}.png')
    plt.show()
    plt.close()

# Plot OmF_stdv for each species group
for group, values in OmF_stdv_all_months.items():
    plt.figure(figsize=(10, 6))
    plt.plot(monthly_timestamps, values, label=f'{group} OmF Stdv', color='orange')
    plt.gcf().autofmt_xdate()
    plt.xlabel('Month')
    plt.ylabel('OmF Standard Deviation')
    plt.title(f'OmF Standard Deviation for {group}')
    plt.legend()
    plt.grid()
    plt.savefig(out_path + f'OmF_Stdv_{group}.png')
    plt.show()
    plt.close()

# %%
# Compute the final statistics
# This section calculate the final statistical metrics based on the accumulated data.
data_mean ={}
data2_mean = {}
data_var = {}

# First, compute the metrics of individual variables  
for var in var_list:
    data_sum[var][N_data == 0] = np.nan
    data2_sum[var][N_data == 0] = np.nan
    
    data_mean[var]  = data_sum[var] / N_data
    data2_mean[var] = data2_sum[var] /N_data
    # var(x) = E[x2] - (E[x])^2
    data_var[var] = data2_mean[var] - data_mean[var]**2
    
oxf_sum[N_data == 0] = np.nan
oxa_sum[N_data == 0] = np.nan
fxa_sum[N_data == 0] = np.nan
# E[xy]
oxf_mean = oxf_sum / N_data
oxa_mean = oxa_sum / N_data
fxa_mean = fxa_sum / N_data

# Then computer metrics of O-F, O-A, etc. based on above computed 
# mean(x-y) = E[x] - E[y]   
OmF_mean = data_mean['obs_obs'] - data_mean['obs_fcst']
OmA_mean = data_mean['obs_obs'] - data_mean['obs_ana']
# var(x-y) = var(x) + var(y) - 2cov(x,y)
# cov(x,y) = E[xy] - E[x]E[y]
OmF_stdv  = np.sqrt(data_var['obs_obs'] + data_var['obs_fcst'] - \
                       2 * (oxf_mean - data_mean['obs_obs']*data_mean['obs_fcst']))
                    
OmA_stdv  = np.sqrt(data_var['obs_obs'] + data_var['obs_ana'] - \
                       2 * (oxa_mean - data_mean['obs_obs']*data_mean['obs_ana']))

OmF_norm_mean = OmF_mean / np.sqrt(data_mean['obs_obsvar'] + data_mean['obs_fcstvar']) 
OmF_norm_stdv = np.sqrt(OmF_stdv**2 / (data_mean['obs_obsvar'] + data_mean['obs_fcstvar']) )
    
# Mask out data points with insufficent observations using the Nmin threshold
# Do NOT apply to N_data
OmF_mean[N_data < Nmin] = np.nan
OmF_stdv[N_data < Nmin] = np.nan
OmF_norm_mean[N_data < Nmin] = np.nan
OmF_norm_stdv[N_data < Nmin] = np.nan
OmA_mean[N_data < Nmin] = np.nan
OmA_stdv[N_data < Nmin] = np.nan

# %%
# Combine metrics of individual species using weighted averaging
OmF_mean = np.nansum(OmF_mean*N_data, axis=1)/np.nansum(N_data,axis=1)
OmF_stdv = np.nansum(OmF_stdv*N_data,axis=1)/np.nansum(N_data,axis=1)
OmF_norm_mean = np.nansum(OmF_norm_mean*N_data, axis=1)/np.nansum(N_data,axis=1)
OmF_norm_stdv = np.nansum(OmF_norm_stdv*N_data,axis=1)/np.nansum(N_data,axis=1)
OmA_mean = np.nansum(OmA_mean*N_data, axis=1)/np.nansum(N_data,axis=1)
OmA_stdv = np.nansum(OmA_stdv*N_data,axis=1)/np.nansum(N_data,axis=1)
Nobs_data = np.nansum(N_data, axis=1)

# %%
species_groups = {
    "SMOS": [0, 1, 2, 3],
    "SMAP": [4, 5, 6, 7],
    "ASCAT": [8, 9, 10],
    "MODIS": [11, 12]
}

group_metrics = {}

for group, species_indices in species_groups.items():
    group_metrics[group] = {}
    group_N_data = np.nansum(N_data[:, species_indices], axis=1)
    
    group_metrics[group]['OmF_mean'] = np.nansum(OmF_mean[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['OmF_stdv'] = np.nansum(OmF_stdv[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['OmF_norm_mean'] = np.nansum(OmF_norm_mean[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['OmF_norm_stdv'] = np.nansum(OmF_norm_stdv[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['OmA_mean'] = np.nansum(OmA_mean[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['OmA_stdv'] = np.nansum(OmA_stdv[:, species_indices] * N_data[:, species_indices], axis=1) / group_N_data
    group_metrics[group]['Nobs_data'] = group_N_data

# %%
import pickle
import os

# Debugging: Check out_path
print("out_path:", out_path)

# Ensure the directory exists
os.makedirs(out_path, exist_ok=True)

# Debugging: Check group_metrics before saving
print("group_metrics:", group_metrics)

# Save the group_metrics dictionary to a file
with open(out_path + 'group_metrics.pkl', 'wb') as f:
    pickle.dump(group_metrics, f)

# Debugging: Check if the file was saved
print("File exists:", os.path.exists(out_path + 'group_metrics.pkl'))

# Load the group_metrics dictionary from the file
with open(out_path + 'group_metrics.pkl', 'rb') as f:
    loaded_group_metrics = pickle.load(f)

# Debugging: Check the loaded dictionary
print("loaded_group_metrics:", loaded_group_metrics)
print("loaded_group_metrics keys:", loaded_group_metrics.keys())

# %%
# Plotting
fig, axes = plt.subplots(2,2, figsize=(18,10))
plt.rcParams.update({'font.size':14})

#Nobs_data = loaded_group_metrics['SMOS']['Nobs_data']
#OmF_mean = loaded_group_metrics['SMOS']['OmF_mean']
#OmF_stdv = loaded_group_metrics['SMOS']['OmF_stdv']
#OmF_norm_mean = loaded_group_metrics['SMOS']['OmF_norm_mean']
#OmF_norm_stdv = loaded_group_metrics['SMOS']['OmF_norm_stdv']

for i in np.arange(2):
    for j in np.arange(2):
        units = '[k]'
        if i == 0 and j == 0:
            tile_data = Nobs_data
            # crange is [cmin, cmax]
            crange =[0, np.ceil((end_time-start_time).days/150)*300]
            colormap = plt.get_cmap('jet',20)
            title_txt = expid + ' Tb Nobs '+ start_time.strftime('%Y%m')+'_'+end_time.strftime('%Y%m')
            units = '[-]'
        if i == 0 and j ==1:
            tile_data = OmF_mean
            crange =[-3, 3]
            colormap = plt.get_cmap('bwr', 15) 
            title_txt = expid + ' Tb O-F mean '+ start_time.strftime('%Y%m')+'_'+end_time.strftime('%Y%m')
        if i == 1 and j == 0:
            tile_data = OmF_stdv
            crange =[0, 15]
            colormap = plt.get_cmap ('jet',15)
            title_txt = expid + ' Tb O-F stdv '+ start_time.strftime('%Y%m')+'_'+end_time.strftime('%Y%m')
        if i == 1 and j == 1:
            tile_data = OmF_norm_stdv
            crange =[0, 15]
            colormap = plt.get_cmap ('jet',15)
            title_txt = expid + ' Tb normalized O-F stdv '+ start_time.strftime('%Y%m%d')+'_'+end_time.strftime('%Y%m%d')

        colormap.set_bad(color='0.9') # light grey, 0-black, 1-white

        # Regrid 1d tile_data to 2d grid_data for map plots
        if '_M09_' in domain: # special case  
            grid_data_M09 = np.zeros((1624, 3856)) + np.nan  
            grid_data_M09[tc['j_indg'],tc['i_indg']] = tile_data
            
            # Reshape the data into 4x4 blocks
            reshaped = grid_data_M09.reshape(1624//4, 4, 3856//4, 4)

            # Combine each 4x4 M09 block into a M36 grid
            if i==0 and j==0:
                grid_data = np.sum(reshaped,axis=(1, 3)) 
            else:
                grid_data = np.nanmean(reshaped,axis=(1, 3))
                
            lat_M36, lon_M36 = smapeasev2_ind2latlon(np.arange(406), np.arange(964),'M36')
            lon_2d,lat_2d = np.meshgrid(lon_M36,lat_M36)
        else:
            grid_data, uy,ux = array2grid(tile_data, lat = tc['com_lat'], lon = tc['com_lon'])
            lon_2d,lat_2d = np.meshgrid(ux, uy)
            
        if 'normalized' in title_txt:
            title_txt = title_txt + '\n' + "avg=%.3f, avg(abs(nstdv-1))=%.3f" % (np.nanmean(grid_data), np.nanmean(np.abs(grid_data-1.)))+' '+units
        elif 'mean' in title_txt:
            title_txt = title_txt + '\n' + "avg=%.3f, avg(abs)=%.3f" % (np.nanmean(grid_data), np.nanmean(np.abs(grid_data)))+' '+units
        else:
            title_txt = title_txt + '\n' + "avg=%.2f" % (np.nanmean(grid_data)) +' '+units                

        if 'normalized' in title_txt:
            grid_data = np.log10(grid_data)
            crange = [-0.6, 0.45]
            
        mm, cs = plotMap(grid_data, ax =axes[i,j], lat=lat_2d, lon=lon_2d, cRange=crange, \
                    title=title_txt, cmap=colormap, bounding=[-60, 80, -180,180])            

plt.tight_layout()
# Save figure to file
fig.savefig('../figures/Map_OmF_'+expid+'_'+start_time.strftime('%Y%m')+'_'+\
                    end_time.strftime('%Y%m')+'.png')
plt.show()
plt.close(fig)
