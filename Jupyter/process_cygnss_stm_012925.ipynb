# %%
import os
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr
from dateutil.relativedelta import relativedelta


from my_functions import read_obsfcstana_extend_datetime
from my_functions import read_obsfcstana

# %%
expt_name = 'long_run_cygd_M36'

start_date = datetime(2018, 8, 1)
end_date = datetime(2019, 8, 1)

start_date_str = start_date.strftime('%Y%m%d')
end_date_str = end_date.strftime('%Y%m%d')

# filename = f"{start_date_str}_{end_date_str}.npz"

# %%
# Produce with extended date_time
# Define the list of years
years = [str(year) for year in range(start_date.year, end_date.year + 1)]
print('years = ', years)

# Define the common file name start
file_name_start = expt_name+'.ens_avg.ldas_ObsFcstAna.20'

# Define the print flag
printflag = False

# Loop over the years
for i in range(len(years)-1):
    # Define the current and next year
    current_year = years[i]
    next_year = years[i+1]
    # Define the list of paths
    paths = []
    for month in range(8, 13):
        path = f'/discover/nobackup/amfox/Experiments/CYGNSS_development/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{current_year}/M{month:02d}'
        paths.append(path)

    for month in range(1, 8):
        path = f'/discover/nobackup/amfox/Experiments/CYGNSS_development/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y{next_year}/M{month:02d}'
        paths.append(path)

# Initialize lists to store the returned values
date_times = []
obs_species_list = []
obs_tilenum_list = []
obs_lon_list = []
obs_lat_list = []
obs_obs_list = []
obs_fcst_list = []
obs_ana_list = []

# Loop over the paths for the current year
for path in paths:
    # Print the current path
    print("Current path:", path)

    # Call the read_obsfcstana function for the current path
    date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana_extend_datetime(path, file_name_start, printflag)
    
    # Append the returned values to the lists
    date_times.append(date_time)
    obs_species_list.append(obs_species)
    obs_tilenum_list.append(obs_tilenum)
    obs_lon_list.append(obs_lon)
    obs_lat_list.append(obs_lat)
    obs_obs_list.append(obs_obs)
    obs_fcst_list.append(obs_fcst)
    obs_ana_list.append(obs_ana)

# Combine the returned values from all paths
date_time_out = np.concatenate(date_times)
obs_species_out = np.concatenate(obs_species_list)
obs_tilenum_out = np.concatenate(obs_tilenum_list)
obs_lon_out = np.concatenate(obs_lon_list)
obs_lat_out = np.concatenate(obs_lat_list)
obs_obs_out = np.concatenate(obs_obs_list)
obs_fcst_out = np.concatenate(obs_fcst_list)
obs_ana_out = np.concatenate(obs_ana_list)

# Save the returned values to a file including the current year in the file name
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_{current_year}.npz',
            date_time=date_time_out,
            obs_species=obs_species_out,
            obs_tilenum=obs_tilenum_out,
            obs_lon=obs_lon_out,
            obs_lat=obs_lat_out,
            obs_obs=obs_obs_out,
            obs_fcst=obs_fcst_out,
            obs_ana=obs_ana_out)
# Out:
# years =  ['2018', '2019']
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M08
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M09
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M10
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M11
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2018/M12
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M01
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M02
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M03
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M04
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M05
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M06
# Current path: /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M07

# %%
# Calculate the daily statistics in observation space

# Define the path directory
path_dir = f'/discover/nobackup/amfox/Experiments/CYGNSS_development/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg'

# Define the common file name start
file_name_start = f'{expt_name}.ens_avg.ldas_ObsFcstAna.'

# Define the print flag
printflag = False

# Initialize lists to store the mean values for each variable and the dates
dates_list = []

cygnss_obs_obs_count_list = []
cygnss_obs_obs_mean_list = []
cygnss_obs_fcst_mean_list = []
cygnss_obs_ana_mean_list = []
cygnss_omf_mean_list = []
cygnss_oma_mean_list = []
cygnss_omf_max_list = []
cygnss_omf_std_list = []
cygnss_oma_std_list = []

# Define the start and end dates
# start_date = datetime.strptime('20150401', '%Y%m%d')
# end_date = datetime.strptime('20210331', '%Y%m%d')

# Loop over the dates
current_date = start_date
while current_date <= end_date:
    # Define the file name for the current date
    file_name = file_name_start + current_date.strftime('%Y%m%d')
    if file_name[-4:] == '0901':
        print('file_name = ', file_name)
    
    # Call the read_obsfcstana function for the current file
    date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana(path_dir, file_name, printflag)

    # Convert the lists to numpy arrays
    c_obs_obs = np.array(obs_obs[obs_species == 1])
    c_obs_fcst = np.array(obs_fcst[obs_species == 1])
    c_obs_ana = np.array(obs_ana[obs_species == 1])
    
    # Calculate the mean values for the variables
    obs_obs_count = len(c_obs_obs)
    obs_obs_mean = np.mean(c_obs_obs)
    obs_fcst_mean = np.mean(c_obs_fcst)
    obs_ana_mean = np.mean(c_obs_ana)
    omf_mean = np.mean(c_obs_obs - c_obs_fcst)
    oma_mean = np.mean(c_obs_obs - c_obs_ana)

    # Calculate the maximum absolute difference between obs_obs and obs_fcst
    if c_obs_fcst.size > 0 and c_obs_obs.size > 0 and c_obs_fcst.shape == c_obs_obs.shape:
        omf_max = np.max(abs(c_obs_obs - c_obs_fcst))
    else:
        omf_max = np.nan
        print('Current date = ', current_date)
    omf_std = np.std(c_obs_obs - c_obs_fcst)
    oma_std = np.std(c_obs_obs - c_obs_ana)

    # Append the mean values to the lists
    cygnss_obs_obs_count_list.append(obs_obs_count)
    cygnss_obs_obs_mean_list.append(obs_obs_mean)
    cygnss_obs_fcst_mean_list.append(obs_fcst_mean)
    cygnss_obs_ana_mean_list.append(obs_ana_mean)
    cygnss_omf_mean_list.append(omf_mean)
    cygnss_oma_mean_list.append(oma_mean)
    cygnss_omf_max_list.append(omf_max)
    cygnss_omf_std_list.append(omf_std)
    cygnss_oma_std_list.append(oma_std)
        
    # Append the current date to the dates list
    dates_list.append(current_date.strftime('%Y%m%d'))

    # Increment the current date by one day
    current_date += timedelta(days=1)
# Out:
# file_name =  long_run_cygd_M36.ens_avg.ldas_ObsFcstAna.20180901
# Current date =  2019-08-01 00:00:00
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_OmF_ts.npz',
         dates_list=dates_list,
         cygnss_obs_obs_count_list=cygnss_obs_obs_count_list,
         cygnss_obs_obs_mean_list=cygnss_obs_obs_mean_list,
         cygnss_obs_fcst_mean_list=cygnss_obs_fcst_mean_list,
         cygnss_obs_ana_mean_list=cygnss_obs_ana_mean_list,
         cygnss_omf_mean_list=cygnss_omf_mean_list,
         cygnss_oma_mean_list=cygnss_oma_mean_list,
         cygnss_omf_max_list=cygnss_omf_max_list,
         cygnss_omf_std_list=cygnss_omf_std_list,
         cygnss_oma_std_list=cygnss_oma_std_list)

# %%
root_directory = f'/discover/nobackup/amfox/Experiments/CYGNSS_development/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

sm_surface_list = []
sm_rootzone_list = []
sm_profile_list = []
precipitation_total_surface_flux_list = []
vegetation_greenness_fraction_list = []
leaf_area_index_list = []
time_stamp_list = []
snow_mass_list = []

current_date = start_date

while current_date <= end_date:
    year_month_directory = os.path.join(root_directory, 
                                        f"Y{current_date.year}", 
                                        f"M{current_date.month:02d}")
    print(year_month_directory)
    for filename in sorted(os.listdir(year_month_directory)):
        if filename.endswith('.nc4') and filename.startswith(f'{expt_name}.tavg24_1d_lnd_Nt.2'):
            file_path = os.path.join(year_month_directory, filename)
            #if current_date.year == 2018 and current_date.month == 12:
            #  print(file_path)
            
            ds = xr.open_dataset(file_path)
            
            # Extract time_stamp
           
            sm_surface = ds['SFMC']
            sm_rootzone = ds['RZMC']
            sm_profile = ds['PRMC']
            precipitation_total_surface_flux = ds['PRECTOTCORRLAND']
            vegetation_greenness_fraction = ds['GRN']
            leaf_area_index = ds['LAI']
            snow_mass = ds['SNOMASLAND']
                        
            sm_surface_list.append(sm_surface)
            sm_rootzone_list.append(sm_rootzone)
            sm_profile_list.append(sm_profile)
            precipitation_total_surface_flux_list.append(precipitation_total_surface_flux)
            vegetation_greenness_fraction_list.append(vegetation_greenness_fraction)
            leaf_area_index_list.append(leaf_area_index)
            snow_mass_list.append(snow_mass)

            ds.close()
    current_date += relativedelta(months=1)
# Out:
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180801_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180802_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180803_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180804_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180805_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180806_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180807_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180808_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180809_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180810_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180811_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180812_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180813_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180814_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180815_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180816_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180817_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180818_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180819_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180820_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180821_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180822_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180823_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180824_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180825_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180826_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180827_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180828_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180829_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180830_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M08/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180831_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180901_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180902_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180903_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180904_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180905_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180906_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180907_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180908_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180909_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180910_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180911_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180912_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180913_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180914_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180915_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180916_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180917_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180918_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180919_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180920_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180921_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180922_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180923_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180924_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180925_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180926_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180927_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180928_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180929_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M09/long_run_cygd_M36.tavg24_1d_lnd_Nt.20180930_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181001_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181002_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181003_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181004_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181005_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181006_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181007_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181008_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181009_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181010_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181011_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181012_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181013_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181014_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181015_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181016_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181017_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181018_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181019_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181020_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181021_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181022_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181023_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181024_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181025_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181026_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181027_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181028_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181029_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181030_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M10/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181031_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181101_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181102_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181103_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181104_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181105_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181106_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181107_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181108_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181109_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181110_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181111_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181112_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181113_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181114_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181115_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181116_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181117_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181118_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181119_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181120_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181121_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181122_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181123_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181124_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181125_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181126_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181127_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181128_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181129_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M11/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181130_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181201_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181202_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181203_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181204_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181205_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181206_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181207_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181208_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181209_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181210_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181211_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181212_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181213_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181214_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181215_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181216_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181217_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181218_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181219_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181220_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181221_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181222_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181223_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181224_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181225_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181226_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181227_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181228_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181229_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181230_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2018/M12/long_run_cygd_M36.tavg24_1d_lnd_Nt.20181231_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190101_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190102_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190103_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190104_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190105_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190106_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190107_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190108_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190109_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190110_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190111_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190112_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190113_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190114_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190115_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190116_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190117_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190118_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190119_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190120_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190121_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190122_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190123_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190124_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190125_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190126_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190127_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190128_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190129_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190130_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M01/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190131_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190201_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190202_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190203_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190204_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190205_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190206_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190207_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190208_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190209_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190210_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190211_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190212_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190213_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190214_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190215_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190216_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190217_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190218_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190219_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190220_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190221_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190222_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190223_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190224_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190225_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190226_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190227_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M02/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190228_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190301_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190302_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190303_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190304_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190305_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190306_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190307_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190308_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190309_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190310_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190311_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190312_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190313_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190314_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190315_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190316_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190317_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190318_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190319_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190320_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190321_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190322_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190323_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190324_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190325_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190326_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190327_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190328_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190329_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190330_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M03/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190331_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190401_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190402_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190403_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190404_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190405_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190406_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190407_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190408_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190409_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190410_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190411_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190412_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190413_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190414_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190415_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190416_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M04/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190417_1200z.nc4
# ...
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190507_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190508_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190509_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190510_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190511_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190512_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190513_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190514_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190515_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190516_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190517_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190518_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190519_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190520_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190521_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190522_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190523_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190524_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190525_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190526_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190527_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190528_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190529_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190530_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M05/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190531_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190601_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190602_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190603_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190604_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190605_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190606_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190607_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190608_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190609_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190610_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190611_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190612_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190613_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190614_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190615_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190616_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190617_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190618_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190619_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190620_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190621_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190622_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190623_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190624_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190625_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190626_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190627_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190628_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190629_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M06/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190630_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190701_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190702_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190703_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190704_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190705_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190706_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190707_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190708_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190709_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190710_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190711_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190712_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190713_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190714_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190715_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190716_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190717_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190718_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190719_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190720_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190721_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190722_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190723_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190724_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190725_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190726_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190727_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190728_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190729_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190730_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M07/long_run_cygd_M36.tavg24_1d_lnd_Nt.20190731_1200z.nc4
# /discover/nobackup/amfox/Experiments/CYGNSS_development/long_run_cygd_M36/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2019/M08

# %%
# Concatenate the sfmc_increment values along the time dimension
print('working on sm_surface_concat')
sm_surface_concat = xr.concat(sm_surface_list, dim='time')
print('working on sm_rootzone_concat')
sm_rootzone_concat = xr.concat(sm_rootzone_list, dim='time')
print('working on sm_profile_concat')
sm_profile_concat = xr.concat(sm_profile_list, dim='time')
print('working on precipitation_total_surface_flux_concat')
precipitation_total_surface_flux_concat = xr.concat(precipitation_total_surface_flux_list, dim='time')
print('working on vegetation_greenness_fraction_concat')
vegetation_greenness_fraction_concat = xr.concat(vegetation_greenness_fraction_list, dim='time')
print('working on leaf_area_index_concat')
leaf_area_index_concat = xr.concat(leaf_area_index_list, dim='time')
print('working on snow_mass')
snow_mass_concat = xr.concat(snow_mass_list, dim='time')
# Out:
# working on sm_surface_concat
# working on sm_rootzone_concat
# working on sm_profile_concat
# working on precipitation_total_surface_flux_concat
# working on vegetation_greenness_fraction_concat
# working on leaf_area_index_concat
# working on snow_mass

# %%
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_tavg24_1d_lnd_Nt_concat.npz',
         sm_surface_concat=sm_surface_concat,
         sm_rootzone_concat=sm_rootzone_concat,
         sm_profile_concat=sm_profile_concat,
         precipitation_total_surface_flux_concat=precipitation_total_surface_flux_concat,
         vegetation_greenness_fraction_concat=vegetation_greenness_fraction_concat,
         leaf_area_index_concat=leaf_area_index_concat,
         snow_mass_concat=snow_mass_concat)

# %%
# Calculate the mean, etc  for each tile along the time dimension
mean_sm_surface = []
std_sm_surface = []
mean_sm_rootzone = []
std_sm_rootzone = []
mean_sm_profile = []
std_sm_profile = []
mean_precipitation_total_surface_flux = []
mean_vegetation_greenness_fraction = []
max_vegetation_greenness_fraction = []
mean_leaf_area_index = []
max_leaf_area_index = []
mean_snow_mass_index = []
std_snow_mass_index = []
max_snow_mass_index = []

for i in range(len(sm_surface_concat['tile'])):
    mean_sm_surface.append(np.mean(sm_surface_concat[:, i]))
    std_sm_surface.append(np.std(sm_surface_concat[:, i]))
    mean_sm_rootzone.append(np.mean(sm_rootzone_concat[:, i]))
    std_sm_rootzone.append(np.std(sm_rootzone_concat[:, i]))
    mean_sm_profile.append(np.mean(sm_profile_concat[:, i]))
    std_sm_profile.append(np.std(sm_profile_concat[:, i]))
    mean_precipitation_total_surface_flux.append(np.mean(precipitation_total_surface_flux_concat[:, i]))
    mean_vegetation_greenness_fraction.append(np.mean(vegetation_greenness_fraction_concat[:, i]))
    max_vegetation_greenness_fraction.append(np.max(vegetation_greenness_fraction_concat[:, i]))
    mean_leaf_area_index.append(np.mean(leaf_area_index_concat[:, i]))
    max_leaf_area_index.append(np.max(leaf_area_index_concat[:, i]))
    mean_snow_mass_index.append(np.mean(snow_mass_concat[:, i]))
    std_snow_mass_index.append(np.std(snow_mass_concat[:, i]))
    max_snow_mass_index.append(np.max(snow_mass_concat[:, i]))

# %%
# Save both the concatenated sfmc_increment and rzmc_increment values to a new npsavez file
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_tavg24_1d_lnd_Nt_stats.npz', 
         mean_sm_surface=mean_sm_surface,
         std_sm_surface=std_sm_surface,
         mean_sm_rootzone=mean_sm_rootzone,
         std_sm_rootzone=std_sm_rootzone,
         mean_sm_profile=mean_sm_profile,
         std_sm_profile=std_sm_profile,
         mean_precipitation_total_surface_flux=mean_precipitation_total_surface_flux,
         mean_vegetation_greenness_fraction=mean_vegetation_greenness_fraction,
         max_vegetation_greenness_fraction=max_vegetation_greenness_fraction,
         mean_leaf_area_index=mean_leaf_area_index,
         max_leaf_area_index=max_leaf_area_index,
         mean_snow_mass_index=mean_snow_mass_index,
         std_snow_mass_index=std_snow_mass_index,
         max_snow_mass_index=max_snow_mass_index)

# %%
# Calculate the mean, etc for each time step along the tile dimension
ts_mean_sm_surface = []
ts_std_sm_surface = []
ts_mean_sm_rootzone = []
ts_std_sm_rootzone = []
ts_mean_sm_profile = []
ts_std_sm_profile = []
ts_mean_precipitation_total_surface_flux = []
ts_mean_vegetation_greenness_fraction = []
ts_max_vegetation_greenness_fraction = []
ts_mean_leaf_area_index = []
ts_max_leaf_area_index = []
ts_mean_snow_mass_index = []
ts_std_snow_mass_index = []
ts_max_snow_mass_index = []

for i in range(len(sm_surface_concat['time'])):
    ts_mean_sm_surface.append(np.mean(sm_surface_concat[i, :]))
    ts_std_sm_surface.append(np.std(sm_surface_concat[i, :]))
    ts_mean_sm_rootzone.append(np.mean(sm_rootzone_concat[i, :]))
    ts_std_sm_rootzone.append(np.std(sm_rootzone_concat[i, :]))
    ts_mean_sm_profile.append(np.mean(sm_profile_concat[i, :]))
    ts_std_sm_profile.append(np.std(sm_profile_concat[i, :]))
    ts_mean_precipitation_total_surface_flux.append(np.mean(precipitation_total_surface_flux_concat[i, :]))
    ts_mean_vegetation_greenness_fraction.append(np.mean(vegetation_greenness_fraction_concat[i, :]))
    ts_max_vegetation_greenness_fraction.append(np.max(vegetation_greenness_fraction_concat[i, :]))
    ts_mean_leaf_area_index.append(np.mean(leaf_area_index_concat[i, :]))
    ts_max_leaf_area_index.append(np.max(leaf_area_index_concat[i, :]))
    ts_mean_snow_mass_index.append(np.mean(snow_mass_concat[i, :]))
    ts_std_snow_mass_index.append(np.std(snow_mass_concat[i, :]))
    ts_max_snow_mass_index.append(np.max(snow_mass_concat[i, :]))

# %%
# Save the time series to a new npsavez file
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_tavg24_1d_lnd_Nt_timeseries.npz', 
         ts_mean_sm_surface=ts_mean_sm_surface,
         ts_std_sm_surface=ts_std_sm_surface,
         ts_mean_sm_rootzone=ts_mean_sm_rootzone,
         ts_std_sm_rootzone=ts_std_sm_rootzone,
         ts_mean_sm_profile=ts_mean_sm_profile,
         ts_std_sm_profile=ts_std_sm_profile,
         ts_mean_precipitation_total_surface_flux=ts_mean_precipitation_total_surface_flux,
         ts_mean_vegetation_greenness_fraction=ts_mean_vegetation_greenness_fraction,
         ts_max_vegetation_greenness_fraction=ts_max_vegetation_greenness_fraction,
         ts_mean_leaf_area_index=ts_mean_leaf_area_index,
         ts_max_leaf_area_index=ts_max_leaf_area_index,
         ts_mean_snow_mass_index=ts_mean_snow_mass_index,
         ts_std_snow_mass_index=ts_std_snow_mass_index,
         ts_max_snow_mass_index=ts_max_snow_mass_index)

# %%
root_directory = f'/discover/nobackup/amfox/Experiments/snow_da_3m/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg'

catdef_incr_list = []
srfexc_incr_list = []
rzexc_incr_list = []
total_incr_list = []
time_stamp_list = []
wesnn1_incr_list = []
wesnn2_incr_list = []
wesnn3_incr_list = []
snow_mass_incr_list = []

current_date = start_date

while current_date <= end_date:
    year_month_directory = os.path.join(root_directory, 
                                        f"Y{current_date.year}", 
                                        f"M{current_date.month:02d}")
    print(year_month_directory)
    for filename in sorted(os.listdir(year_month_directory)):
        if filename.endswith('.nc4') and not filename.endswith('z.nc4') and filename.startswith(f'{expt_name}.catch_progn_incr.2'):
            file_path = os.path.join(year_month_directory, filename)
            
            ds = xr.open_dataset(file_path)
            
            # Extract time_stamp
            time_stamp = ds['time_stamp']
            
            catdef_incr = ds['CATDEF_INCR']
            srfexc_incr = ds['SRFEXC_INCR']
            rzexc_incr = ds['RZEXC_INCR']
            wesnn1_incr = ds['WESNN1_INCR']
            wesnn2_incr = ds['WESNN2_INCR']
            wesnn3_incr = ds['WESNN3_INCR']
            
            total_incr = srfexc_incr + rzexc_incr - catdef_incr
            snow_mass_incr = wesnn1_incr + wesnn2_incr + wesnn3_incr
                       
            time_stamp_list.append(time_stamp)    
            catdef_incr_list.append(catdef_incr)
            srfexc_incr_list.append(srfexc_incr)
            rzexc_incr_list.append(rzexc_incr)
            total_incr_list.append(total_incr)
            wesnn1_incr_list.append(wesnn1_incr)
            wesnn2_incr_list.append(wesnn2_incr)
            wesnn3_incr_list.append(wesnn3_incr)
            snow_mass_incr_list.append(snow_mass_incr)

            ds.close()
    current_date += relativedelta(months=1)
# Out:
# /discover/nobackup/amfox/Experiments/snow_da_3m/DAv7_M36_SMAP_ASCAT_up13/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01
# /discover/nobackup/amfox/Experiments/snow_da_3m/DAv7_M36_SMAP_ASCAT_up13/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M02
# /discover/nobackup/amfox/Experiments/snow_da_3m/DAv7_M36_SMAP_ASCAT_up13/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M03
# /discover/nobackup/amfox/Experiments/snow_da_3m/DAv7_M36_SMAP_ASCAT_up13/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M04

# %%
# Concatenate the sfmc_increment values along the time dimension
print('working on catdef_incr')
catdef_incr_concat = xr.concat(catdef_incr_list, dim='time')
print('working on srfexc_incr')
srfexc_incr_concat = xr.concat(srfexc_incr_list, dim='time')
print('working on catdef_incr')
rzexc_incr_concat = xr.concat(rzexc_incr_list, dim='time')
print('working on total_incr')
total_incr_concat = xr.concat(total_incr_list, dim='time')
print('working on wesnn1_incr')
wesnn1_incr_concat = xr.concat(wesnn1_incr_list, dim='time')
print('working on wesnn2_incr')
wesnn2_incr_concat = xr.concat(wesnn2_incr_list, dim='time')
print('working on wesnn3_incr')
wesnn3_incr_concat = xr.concat(wesnn3_incr_list, dim='time')
print('working on snow_mass_incr')
snow_mass_incr_concat = xr.concat(snow_mass_incr_list, dim='time')
# Out:
# working on catdef_incr
# working on srfexc_incr
# working on catdef_incr
# working on total_incr
# working on wesnn1_incr
# working on wesnn2_incr
# working on wesnn3_incr
# working on snow_mass_incr

# %%
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}catch_progn_incr_concat.npz',
         catdef_incr_concat=catdef_incr_concat,
         srfexc_incr_concat=srfexc_incr_concat,
         rzexc_incr_concat=rzexc_incr_concat,
         total_incr_concat=total_incr_concat,
         wesnn1_incr_concat=wesnn1_incr_concat,
         wesnn2_incr_concat=wesnn2_incr_concat,
         wesnn3_incr_concat=wesnn3_incr_concat,
         snow_mass_incr_concat=snow_mass_incr_concat,
         time_stamp_concat=time_stamp_concat)

# %%
# Calculate the mean, etc for each time step along the tile dimension
ts_mean_catdef_incr = []
ts_std_catdef_incr = []
ts_mean_surfexc_incr = []
ts_std_surfexc_incr = []
ts_mean_rzexc_incr = []
ts_std_rzexc_incr = []
ts_mean_total_incr = []
ts_std_total_incr = []
number_of_incr = []

ts_mean_snow_mass_incr = []
ts_std_snow_mass_incr = []
number_of_snow_mass_incr = []

for i in range(len(total_incr_concat['tile'])):
    non_zero_values = catdef_incr_concat[:, i].where(catdef_incr_concat[:, i] != 0.0)
    ts_mean_catdef_incr.append(non_zero_values.mean().values)
    ts_std_catdef_incr.append(non_zero_values.std().values)
    non_zero_values_surfexc = srfexc_incr_concat[:, i].where(srfexc_incr_concat[:, i] != 0.0)
    ts_mean_surfexc_incr.append(non_zero_values_surfexc.mean().values)
    ts_std_surfexc_incr.append(non_zero_values_surfexc.std().values)
    non_zero_values_rzexc = rzexc_incr_concat[:, i].where(rzexc_incr_concat[:, i] != 0.0)
    ts_mean_rzexc_incr.append(non_zero_values_rzexc.mean().values)
    ts_std_rzexc_incr.append(non_zero_values_rzexc.std().values)
    non_zero_values_total = total_incr_concat[:, i].where(total_incr_concat[:, i] != 0.0)
    ts_mean_total_incr.append(non_zero_values_total.mean().values)
    ts_std_total_incr.append(non_zero_values_total.std().values)
    number_of_incr.append(np.sum(total_incr_concat[:, i] != 0.0))
    
    non_zero_values_snow = snow_mass_incr_concat[:, i].where(snow_mass_incr_concat[:, i] != 0.0)
    ts_mean_snow_mass_incr.append(non_zero_values_snow.mean().values)
    ts_std_snow_mass_incr.append(non_zero_values_snow.std().values)
    number_of_snow_mass_incr.append(np.sum(snow_mass_incr_concat[:, i] != 0.0))

# %%
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_catch_progn_incr_stats_v2.npz', 
         ts_mean_catdef_incr=ts_mean_catdef_incr,
         ts_std_catdef_incr=ts_std_catdef_incr,
         ts_mean_surfexc_incr=ts_mean_surfexc_incr,
         ts_std_surfexc_incr=ts_std_surfexc_incr,
         ts_mean_rzexc_incr=ts_mean_rzexc_incr,
         ts_std_rzexc_incr=ts_std_rzexc_incr,
         ts_mean_total_incr=ts_mean_total_incr,
         ts_std_total_incr=ts_std_total_incr,
         number_of_incr=number_of_incr,
         ts_mean_snow_mass_incr=ts_mean_snow_mass_incr,
         ts_std_snow_mass_incr=ts_std_snow_mass_incr,
         number_of_snow_mass_incr=number_of_snow_mass_incr)

# %%
import xarray as xr
from mapper_functions import plot_global_tight

ds = xr.open_dataset('DAv7_M36.inst3_1d_lndfcstana_Nt.20150901.nc4')
lon = ds['lon']
lat = ds['lat']
n_tile = len(lat)

# %%
expt_name2 = 'DAv7_M36_SMAP_ASCAT_up13'
data = np.load(f'{expt_name2}_{start_date_str}_{end_date_str}_catch_progn_incr_stats_v2.npz')

ex2_number_of_incr      = data['number_of_incr']
ex2_std_sfexc_increment = data['ts_std_surfexc_incr']
ex2_std_rzexc_increment = data['ts_std_rzexc_incr']
ex2_std_total_increment = data['ts_std_total_incr']

obarray = np.empty([n_tile, 3])
obarray.fill(np.nan)
obarray[:, 1] = lon
obarray[:, 2] = lat

obarray[:, 0] = ex2_number_of_incr
obarray[:, 0][obarray[:, 0] == 0] = np.nan
plot_global_tight(obarray,False,f'{expt_name2}:\n Number of srfexc increments','(Incrs)', 0, 400)

# %%
expt_name3 = 'DAv7_M36_SMAP_ASCAT_up14'
data = np.load(f'{expt_name3}_{start_date_str}_{end_date_str}_catch_progn_incr_stats_v2.npz')

ex3_number_of_incr      = data['number_of_incr']
ex3_std_sfexc_increment = data['ts_std_surfexc_incr']
ex3_std_rzexc_increment = data['ts_std_rzexc_incr']
ex3_std_total_increment = data['ts_std_total_incr']

obarray = np.empty([n_tile, 3])
obarray.fill(np.nan)
obarray[:, 1] = lon
obarray[:, 2] = lat

obarray[:, 0] = ex3_number_of_incr
obarray[:, 0][obarray[:, 0] == 0] = np.nan
plot_global_tight(obarray,False,f'{expt_name3}:\n Number of srfexc increments','(Incrs)', 0, 400)

# %%
expt_name4 = 'DAv7_M36_SMAP_ASCAT_SNOW_up14'
data = np.load(f'../test_data/snow_da/{expt_name4}_{start_date_str}_{end_date_str}_catch_progn_incr_stats_v2.npz')

ex4_number_of_incr      = data['number_of_incr']
ex4_std_sfexc_increment = data['ts_std_surfexc_incr']
ex4_std_rzexc_increment = data['ts_std_rzexc_incr']
ex4_std_total_increment = data['ts_std_total_incr']

ex4_number_of_snow_mass_incr = data['number_of_snow_mass_incr']
ex4_std_snow_mass_increment = data['ts_std_snow_mass_incr']
ex4_mean_snow_mass_increment = data['ts_mean_snow_mass_incr']

obarray = np.empty([n_tile, 3])
obarray.fill(np.nan)
obarray[:, 1] = lon
obarray[:, 2] = lat

obarray[:, 0] = ex4_number_of_incr
obarray[:, 0][obarray[:, 0] == 0] = np.nan
plot_global_tight(obarray,False,f'{expt_name4}:\n Number of srfexc increments','(Incrs)', 0, 400) 

obarray[:, 0] = ex4_number_of_snow_mass_incr
obarray[:, 0][obarray[:, 0] == 0] = np.nan
maxval = np.nanmax(obarray[:, 0]) 
minval = np.nanmin(obarray[:, 0]) 
plot_global_tight(obarray,False,f'{expt_name4}:\n Number of snow mass increments (Max: {maxval:.3g} Min: {minval:.3g})','(Incrs)', 0, 200)

obarray[:, 0] = ex4_std_snow_mass_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
maxval = np.nanmax(obarray[:, 0]) 
minval = np.nanmin(obarray[:, 0]) 
plot_global_tight(obarray,False,f'{expt_name4}:\n Stddev snow mass increments (Max: {maxval:.3g} Min: {minval:.3g})','(kg/m^2)', 0, 3)

obarray[:, 0] = ex4_mean_snow_mass_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
maxval = np.nanmax(obarray[:, 0])
minval = np.nanmin(obarray[:, 0])
plot_global_tight(obarray,False,f'{expt_name4}:\n Mean snow mass increment (Max: {maxval:.3g} Min: {minval:.3g})','(kg/m^2)', -5, 5)

# %%
obarray[:, 0] = ex2_number_of_incr - ex3_number_of_incr
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray,False,f'{expt_name2} - {expt_name3}:\n Difference in number of increments (Max: {maxval:.3g} Min: {minval:.3g})','(Incrs)', -200, 200)

# %%
obarray[:, 0] = ex4_number_of_incr - ex3_number_of_incr
obarray[:, 0][obarray[:, 0] == 0] = np.nan
plot_global_tight(obarray,False,f'{expt_name4} - {expt_name3}:\n Difference in number of increments','(Incrs)', -200, 200)

# %%
obarray[:, 0] = ex2_std_sfexc_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
print(np.nanmax(ex2_std_sfexc_increment))
print(np.nanmin(ex2_std_sfexc_increment))     
plot_global_tight(obarray,False,f'{expt_name2}:\n StdDev of srfexc incr','(mm)', 0, 1)
# Out:
# 3.2184250354766846
# 0.0

# %%
obarray[:, 0] = ex3_std_sfexc_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
print(np.nanmax(ex3_std_sfexc_increment))
print(np.nanmin(ex3_std_sfexc_increment))     
plot_global_tight(obarray,False,f'{expt_name3}:\n StdDev of srfexc incr','(mm)', 0, 1)
# Out:
# 3.2184250354766846
# 0.0

# %%
obarray[:, 0] = ex4_std_sfexc_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
print(np.nanmax(ex4_std_sfexc_increment))
print(np.nanmin(ex4_std_sfexc_increment))     
plot_global_tight(obarray,False,f'{expt_name4}:\n StdDev of srfexc incr','(mm)', 0, 1)
# Out:
# 3.5894289016723633
# 0.0

# %%
obarray[:, 0] = ex2_std_sfexc_increment - ex3_std_sfexc_increment
maxval = np.nanmax(obarray[:, 0]) 
minval = np.nanmin(obarray[:, 0]) 
plot_global_tight(obarray,False,f'{expt_name2} - {expt_name3}:\n Difference in StdDev of increments (Max: {maxval:.3g} Min: {minval:.3g})','(Incrs)', -200, 200)

# %%
obarray[:, 0] = ex4_std_sfexc_increment - ex3_std_sfexc_increment
obarray[:, 0][obarray[:, 0] == 0] = np.nan
print(np.nanmax(ex4_std_sfexc_increment - ex3_std_sfexc_increment))
print(np.nanmin(ex4_std_sfexc_increment - ex3_std_sfexc_increment))     
plot_global_tight(obarray,False,f'{expt_name4} - {expt_name4}:\n Difference in StdDev of srfexc incr','(mm)', -0.5, 0.5)
# Out:
# 0.7513435781002045
# -1.0419576242566109

# %%
# Make histogram of the difference array
maxdiff = np.nanmax(ex4_std_sfexc_increment - ex3_std_sfexc_increment)
mindiff = np.nanmin(ex4_std_sfexc_increment - ex3_std_sfexc_increment)

plt.hist(obarray[:, 0], bins=100, range=(-0.05, 0.05))
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.title(f'Histogram of difference in srfexc incr stddev\n Max: {maxdiff:.3g}, Min: {mindiff:.3g}')
plt.show()
