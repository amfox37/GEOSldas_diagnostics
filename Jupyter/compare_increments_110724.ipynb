# %%
import os
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

import xarray as xr

from mapper_functions import plot_global_tight, plot_global_tight_pcm
from my_functions import read_obsfcstana_extend_datetime

# %%
file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SMAP_ASCAT_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SMAP_ASCAT_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_sas = ds['CATDEF_INCR']
srfexc_incr_sas = ds['SRFEXC_INCR']
rzexc_incr_sas = ds['RZEXC_INCR']
wesnn1_incr_sas = ds['WESNN1_INCR']
wesnn2_incr_sas = ds['WESNN2_INCR']
wesnn3_incr_sas = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/DAv7_M36_SMAP_ASCAT_SNOW_up11/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/DAv7_M36_SMAP_ASCAT_SNOW_up11.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
        
catdef_incr_11 = ds['CATDEF_INCR']
srfexc_incr_11 = ds['SRFEXC_INCR']
rzexc_incr_11 = ds['RZEXC_INCR']
wesnn1_incr_11 = ds['WESNN1_INCR']
wesnn2_incr_11 = ds['WESNN2_INCR']
wesnn3_incr_11 = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/DAv7_M36_SMAP_ASCAT_SNOW_up13/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/DAv7_M36_SMAP_ASCAT_SNOW_up13.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
        
catdef_incr_13 = ds['CATDEF_INCR']
srfexc_incr_13 = ds['SRFEXC_INCR']
rzexc_incr_13 = ds['RZEXC_INCR']
wesnn1_incr_13 = ds['WESNN1_INCR']
wesnn2_incr_13 = ds['WESNN2_INCR']
wesnn3_incr_13 = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SMAP_ASCAT_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SMAP_ASCAT_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_nsa = ds['CATDEF_INCR']
srfexc_incr_nsa = ds['SRFEXC_INCR']
rzexc_incr_nsa = ds['RZEXC_INCR']
wesnn1_incr_nsa = ds['WESNN1_INCR']
wesnn2_incr_nsa = ds['WESNN2_INCR']
wesnn3_incr_nsa = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_ns = ds['CATDEF_INCR']
srfexc_incr_ns = ds['SRFEXC_INCR']
rzexc_incr_ns = ds['RZEXC_INCR']
wesnn1_incr_ns = ds['WESNN1_INCR']
wesnn2_incr_ns = ds['WESNN2_INCR']
wesnn3_incr_ns = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_incr_DAv7_M36_SMAP_ASCAT_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_incr_DAv7_M36_SMAP_ASCAT_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_test = ds['CATDEF_INCR']
srfexc_incr_test = ds['SRFEXC_INCR']
rzexc_incr_test = ds['RZEXC_INCR']
wesnn1_incr_test = ds['WESNN1_INCR']
wesnn2_incr_test = ds['WESNN2_INCR']
wesnn3_incr_test = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SMAP_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SMAP_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_ss = ds['CATDEF_INCR']
srfexc_incr_ss = ds['SRFEXC_INCR']
rzexc_incr_ss = ds['RZEXC_INCR']
wesnn1_incr_ss = ds['WESNN1_INCR']
wesnn2_incr_ss = ds['WESNN2_INCR']
wesnn3_incr_ss = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_ASCAT_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_ASCAT_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_as = ds['CATDEF_INCR']
srfexc_incr_as = ds['SRFEXC_INCR']
rzexc_incr_as = ds['RZEXC_INCR']
wesnn1_incr_as = ds['WESNN1_INCR']
wesnn2_incr_as = ds['WESNN2_INCR']
wesnn3_incr_as = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SMAP_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SMAP_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_s = ds['CATDEF_INCR']
srfexc_incr_s = ds['SRFEXC_INCR']
rzexc_incr_s = ds['RZEXC_INCR']
wesnn1_incr_s = ds['WESNN1_INCR']
wesnn2_incr_s = ds['WESNN2_INCR']
wesnn3_incr_s = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/QC_test_DAv7_M36_ASCAT_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/QC_test_DAv7_M36_ASCAT_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_qs = ds['CATDEF_INCR']
srfexc_incr_qs = ds['SRFEXC_INCR']
rzexc_incr_qs = ds['RZEXC_INCR']
wesnn1_incr_qs = ds['WESNN1_INCR']
wesnn2_incr_qs = ds['WESNN2_INCR']
wesnn3_incr_qs = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/QC_test_DAv7_M36_ASCAT_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/QC_test_DAv7_M36_ASCAT_SNOW_up_new.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_qss = ds['CATDEF_INCR']
srfexc_incr_qss = ds['SRFEXC_INCR']
rzexc_incr_qss = ds['RZEXC_INCR']
wesnn1_incr_qss = ds['WESNN1_INCR']
wesnn2_incr_qss = ds['WESNN2_INCR']
wesnn3_incr_qss = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/DAv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/DAv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14 = ds['CATDEF_INCR']
srfexc_incr_14 = ds['SRFEXC_INCR']
rzexc_incr_14 = ds['RZEXC_INCR']
wesnn1_incr_14 = ds['WESNN1_INCR']
wesnn2_incr_14 = ds['WESNN2_INCR']
wesnn3_incr_14 = ds['WESNN3_INCR']
            
ds.close()


file = '/discover/nobackup/amfox/Experiments/snda_2day/test_DAv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test_DAv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14_test = ds['CATDEF_INCR']
srfexc_incr_14_test = ds['SRFEXC_INCR']
rzexc_incr_14_test = ds['RZEXC_INCR']
wesnn1_incr_14_test = ds['WESNN1_INCR']
wesnn2_incr_14_test = ds['WESNN2_INCR']
wesnn3_incr_14_test = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/test2_DAv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/test2_DAv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14_test2 = ds['CATDEF_INCR']
srfexc_incr_14_test2 = ds['SRFEXC_INCR']
rzexc_incr_14_test2 = ds['RZEXC_INCR']
wesnn1_incr_14_test2 = ds['WESNN1_INCR']
wesnn2_incr_14_test2 = ds['WESNN2_INCR']
wesnn3_incr_14_test2 = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/OLv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/OLv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14_OL = ds['CATDEF_INCR']
srfexc_incr_14_OL = ds['SRFEXC_INCR']
rzexc_incr_14_OL = ds['RZEXC_INCR']
wesnn1_incr_14_OL = ds['WESNN1_INCR']
wesnn2_incr_14_OL = ds['WESNN2_INCR']
wesnn3_incr_14_OL = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snow_da_3m/OLv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/OLv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14_OL3m = ds['CATDEF_INCR']
srfexc_incr_14_OL3m = ds['SRFEXC_INCR']
rzexc_incr_14_OL3m = ds['RZEXC_INCR']
wesnn1_incr_14_OL3m = ds['WESNN1_INCR']
wesnn2_incr_14_OL3m = ds['WESNN2_INCR']
wesnn3_incr_14_OL3m = ds['WESNN3_INCR']
            
ds.close()

file = '/discover/nobackup/amfox/Experiments/snda_2day/testXX_DAv7_M36_SMAP_ASCAT_SNOW_up14/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2016/M01/testXX_DAv7_M36_SMAP_ASCAT_SNOW_up14.catch_progn_incr.20160101_1200z.nc4'

ds = xr.open_dataset(file)
            
lon = ds['lon']
lat = ds['lat']

catdef_incr_14_testXX = ds['CATDEF_INCR']
srfexc_incr_14_testXX = ds['SRFEXC_INCR']
rzexc_incr_14_testXX = ds['RZEXC_INCR']
wesnn1_incr_14_testXX = ds['WESNN1_INCR']
wesnn2_incr_14_testXX = ds['WESNN2_INCR']
wesnn3_incr_14_testXX = ds['WESNN3_INCR']
            
ds.close()

# %%
# Compare the two srfexc_incr variables using scatter plot
plt.scatter(srfexc_incr_14_test, srfexc_incr_14_test2, s=1)
plt.xlabel('srfexc_incr_14_test')
plt.ylabel('srfexc_incr_14_test2')
plt.gca().set_aspect('equal', adjustable='box')
plt.grid()
plt.title('Scatter plot of srfexc_incr values: 20160101_1200z')
plt.show()

# %%
difference = srfexc_incr_14_OL.values - srfexc_incr_14_OL3m.values
print('Difference srfexc_incr Max: ', np.max(difference))
print('Difference srfexc_incr Min: ', np.min(difference))

difference = rzexc_incr_14_OL.values - rzexc_incr_14_OL3m.values
print('Difference rzexc_incr Max: ', np.max(difference))
print('Difference rzexc_incr Min: ', np.min(difference))

difference = wesnn1_incr_14_OL.values - wesnn1_incr_14_OL3m.values
print('Difference wesnn1_incr Max: ', np.max(difference))
print('Difference wesnn1_incr Min: ', np.min(difference))
# Out:
# Difference srfexc_incr Max:  0.0
# Difference srfexc_incr Min:  0.0
# Difference rzexc_incr Max:  0.0
# Difference rzexc_incr Min:  0.0
# Difference wesnn1_incr Max:  0.0
# Difference wesnn1_incr Min:  0.0

# %%
difference = srfexc_incr_14_testXX.values - srfexc_incr_14_test2.values
print('Difference srfexc_incr Max: ', np.max(difference))
print('Difference srfexc_incr Min: ', np.min(difference))

difference = rzexc_incr_14_testXX.values - rzexc_incr_14_test2.values
print('Difference rzexc_incr Max: ', np.max(difference))
print('Difference rzexc_incr Min: ', np.min(difference))

difference = wesnn1_incr_14_testXX.values - wesnn1_incr_14_test2.values
print('Difference wesnn1_incr Max: ', np.max(difference))
print('Difference wesnn1_incr Min: ', np.min(difference))

plt.scatter(srfexc_incr_14_testXX, srfexc_incr_14_test2, s=1)
plt.xlabel('srfexc_incr_14_testXX')
plt.ylabel('srfexc_incr_14_test2')
plt.gca().set_aspect('equal', adjustable='box')
plt.grid()
plt.title('Scatter plot of srfexc_incr values: 20160101_1200z\n Testing equivalence of up_14')
plt.show()

plt.scatter(wesnn1_incr_14_testXX, wesnn1_incr_14_test2, s=1)
plt.xlabel('srfexc_incr_14_testXX')
plt.ylabel('srfexc_incr_14_test2')
plt.gca().set_aspect('equal', adjustable='box')
plt.grid()
plt.title('Scatter plot of srfexc_incr values: 20160101_1200z\n Testing equivalence of up_14')
plt.show()
# Out:
# Difference srfexc_incr Max:  9.0897083e-07
# Difference srfexc_incr Min:  -7.9348683e-07
# Difference rzexc_incr Max:  2.9951334e-06
# Difference rzexc_incr Min:  -1.758337e-06
# Difference wesnn1_incr Max:  4.6551228e-05
# Difference wesnn1_incr Min:  -1.0550022e-05

# %%
STOP
srfexc_incr_n_array = srfexc_incr_14_testXX.values
srfexc_incr_13_array = srfexc_incr_14_test2.values
#srfexc_incr_n_array = srfexc_incr_test.values
#srfexc_incr_13_array = srfexc_incr_14.values

difference = srfexc_incr_n_array - srfexc_incr_13_array

# Remove zero values in srfexc_incr_n_array and the corresponding indices in srfexc_incr_13_array
non_zero_indices = srfexc_incr_n_array != 0
srfexc_incr_n_array = srfexc_incr_n_array[non_zero_indices]
srfexc_incr_13_array = srfexc_incr_13_array[non_zero_indices]
difference = difference[non_zero_indices]

maxdiff = (np.max(difference))
print(maxdiff)
mindiff = (np.min(difference))
print(mindiff)

# Make histogram of the difference array
plt.hist(difference, bins=100)
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.title(f'Histogram of srfexc incr difference\n Max: {maxdiff:.3g}, Min: {mindiff:.3g}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 STOP
#       2 srfexc_incr_n_array = srfexc_incr_14_testXX.values
#       3 srfexc_incr_13_array = srfexc_incr_14_test2.values
#
# NameError: name 'STOP' is not defined

# %%
n_tiles = len(srfexc_incr_n_array)
obarray = np.empty((n_tiles, 3))
obarray.fill(np.nan)

# Ensure lon and lat are numpy arrays
lon_array = lon.values
lat_array = lat.values

# Reshape non_zero_indices to be 1D
non_zero_indices = non_zero_indices.flatten()

# Apply the non_zero_indices to lon and lat arrays
obarray[:, 1] = lon_array[non_zero_indices]
obarray[:, 2] = lat_array[non_zero_indices]

obarray[:, 0] = srfexc_incr_n_array
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0])
plot_global_tight(obarray, False, f'srfexc_incr (new_13): 20160101 1200z\n Max: {maxval:.3g} Min: {minval:.3g}', '-', -3, 3)

# %%
obarray[:, 0] = difference
plot_global_tight(obarray, False, f'Difference (Without snow minus with snow): 20160101 1200z\n Max: {maxdiff:.3g} Min: {mindiff:.3g}', '-', -0.03, 0.03)

# %%
#swe_incr = wesnn1_incr_qss.values + wesnn2_incr_qss.values + wesnn3_incr_qss.values

swe_incr = wesnn1_incr_11.values + wesnn2_incr_11.values + wesnn3_incr_11.values

nonezero = swe_incr != 0

maxswe = np.max(swe_incr)
minswe = np.min(swe_incr)

n_tiles = len(swe_incr[nonezero])
print(n_tiles)
obarray = np.empty((n_tiles, 3))
obarray.fill(np.nan)

obarray[:, 0] = swe_incr[nonezero]
obarray[:, 1] = lon_array[nonezero.flatten()]
obarray[:, 2] = lat_array[nonezero.flatten()]


plot_global_tight(obarray, False, f'wesn increment (new_13): 20160101 1200z\n Max: {maxswe:.3g} Min: {minswe:.3g}', '-', -5, 5)

# %%
path = '/discover/nobackup/amfox/Experiments/snda_2day/QC_test_DAv7_M36_ASCAT_up_new/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M01'
file_name_start = 'QC_test_DAv7_M36_ASCAT_up_new.ens_avg.ldas_ObsFcstAna.20160101_12'
printflag = True
date_time, obs_species, obs_tilenum, obs_lon, obs_lat, obs_obs, obs_obsvar, obs_fcst, obs_fcstvar, obs_ana, obs_anavar = read_obsfcstana_extend_datetime(path, file_name_start, printflag)

date_time = np.array(date_time)
obs_species = np.array(obs_species)
obs_tilenum = np.array(obs_tilenum)
obs_lon = np.array(obs_lon)
obs_lat = np.array(obs_lat)
obs_obs = np.array(obs_obs)
obs_fcst = np.array(obs_fcst)
obs_ana = np.array(obs_ana)


path = '/discover/nobackup/amfox/Experiments/snda_2day/QC_test_DAv7_M36_ASCAT_SNOW_up_new/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2016/M01'
file_name_start = 'QC_test_DAv7_M36_ASCAT_SNOW_up_new.ens_avg.ldas_ObsFcstAna.20160101_12'
printflag = True
date_time2, obs_species2, obs_tilenum2, obs_lon2, obs_lat2, obs_obs2, obs_obsvar2, obs_fcst2, obs_fcstvar2, obs_ana2, obs_anavar2 = read_obsfcstana_extend_datetime(path, file_name_start, printflag)

date_time_sa = np.array(date_time2)
obs_species_sa = np.array(obs_species2)
obs_tilenum_sa = np.array(obs_tilenum2)
obs_lon_sa = np.array(obs_lon2)
obs_lat_sa = np.array(obs_lat2)
obs_obs_sa = np.array(obs_obs2)
obs_fcst_sa = np.array(obs_fcst2)
obs_ana_sa = np.array(obs_ana2)

# %%
for i in range(1, 6):
    print(f'N Obs (ASCAT only): {i},', len(obs_obs[obs_species == i]))
    print(f'N Obs (ASCAT & SCF): {i},', len(obs_obs_sa[obs_species_sa == i]))
    print(f'Mean Obs (ASCAT only): {i}, {np.mean(obs_obs[obs_species == i]):.5g}')
    print(f'Mean Obs (ASCAT & SCF): {i}, {np.mean(obs_obs_sa[obs_species_sa == i]):.5g}') 
    print(f'Std Obs (ASCAT only): {i}, {np.mean(obs_obs[obs_species == i]):.5g}')
    print(f'Std Obs (ASCAT & SCF): {i}, {np.mean(obs_obs_sa[obs_species_sa == i]):.5g}')     
    
    print(f'Mean Fcst (ASCAT only): {i}, {np.mean(obs_fcst[obs_species == i]):.5g}')
    print(f'Mean Fcst (ASCAT & SCF): {i}, {np.mean(obs_fcst_sa[obs_species_sa == i]):.5g}') 
    
    print(f'Mean Ana (ASCAT only): {i}, {np.mean(obs_ana[obs_species == i]):.5g}')
    print(f'Mean Ana (ASCAT & SCF): {i}, {np.mean(obs_ana_sa[obs_species_sa == i]):.5g}')
    
    print('')

# %%
i = 1

innov = obs_obs[obs_species == i] - obs_fcst[obs_species == i]
innov_s = obs_obs_sa[obs_species == i] - obs_fcst_sa[obs_species == i]

incr = obs_fcst[obs_species == i] - obs_ana[obs_species == i]
incr_s = obs_fcst_sa[obs_species == i] - obs_ana_sa[obs_species == i]

# %%
n_tiles = len(innov)
obarray = np.empty((n_tiles, 3))
obarray.fill(np.nan)

# Apply the non_zero_indices to lon and lat arrays
obarray[:, 1] = obs_lon[obs_species == i]
obarray[:, 2] = obs_lat[obs_species == i]

obarray[:, 0] = innov
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray, False, f'SM innov (new_13): 20160101 1200z\n Max: {maxval:.4g} Min: {minval:.4g}', '-', -0.2, 0.2)

# %%
obarray[:, 0] = innov_s
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray, False, f'SM innov_s (new_13): 20160101 1200z\n Max: {maxval:.4g} Min: {minval:.4g}', '-', -0.2, 0.2)

# %%
obarray[:, 0] = incr
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray, False, f'SM incr (new_13, passive snow): 20160101 1200z\n Max: {maxval:.4g} Min: {minval:.4g}', '-', -0.1, 0.1)

# %%
obarray[:, 0] = incr_s
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray, False, f'SM incr (new_13, active snow): 20160101 1200z\n Max: {maxval:.4g} Min: {minval:.4g}', '-', -0.1, 0.1)

# %%
plt.scatter(incr, incr_s, s=1)
plt.xlabel('new_13 (Snow passive)')
plt.ylabel('new_13 (Snow active)')
plt.gca().set_aspect('equal', adjustable='box')
plt.grid()
plt.title('Scatter plot of SM incr values: 20160101_1200z\n South America only')
plt.show()

# %%
incr_diff = incr - incr_s
obarray[:, 0] = incr_diff
maxval = np.max(obarray[:, 0]) 
minval = np.min(obarray[:, 0]) 
plot_global_tight(obarray, False, f'SM incr_diff (new_13): 20160101 1200z\n Max: {maxval:.3g} Min: {minval:.3g}', '-', -0.001, 0.001)

# %%
# Make histogram of the difference array
plt.hist(incr_diff, bins=100)
plt.xlabel('Difference')
plt.ylabel('Frequency')
plt.title(f'Histogram of SM incr difference\n Max: {maxval:.3g}, Min: {minval:.3g}')
plt.show()
