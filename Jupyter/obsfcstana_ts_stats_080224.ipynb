# %%
import xarray as xr
import numpy as np
from datetime import datetime, timedelta

from mapper_functions import plot_global

# %%
expt_name = 'DAv7_M36_MULTI_type_13_comb_fp_scaled'

start_date = datetime(2015, 4, 1)
end_date = datetime(2021, 4, 1)

start_date_str = start_date.strftime('%Y%m%d')
end_date_str = end_date.strftime('%Y%m%d')

# %%
# Specify the path to the netCDF file
file_path = f'/discover/nobackup/amfox/Experiments/{expt_name}/{expt_name}/output/SMAP_EASEv2_M36_GLOBAL/cat/ens_avg/Y2015/M04/{expt_name}.catch_progn_incr.20150402.nc4'

# Open the netCDF file
dataset = xr.open_dataset(file_path)

# Extract the lon and lat variables
lon = dataset['lon']
lat = dataset['lat']

# Print the dimensions of the variables
print(f"Dimensions of lon: {lon.shape}")
print(f"Dimensions of lat: {lat.shape}")
# Out:
# Dimensions of lon: (112573,)
# Dimensions of lat: (112573,)

# %%
# Open each of the saved files

data_2015 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2015.npz', allow_pickle=True)
data_2016 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2016.npz', allow_pickle=True)
data_2017 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2017.npz', allow_pickle=True)
data_2018 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2018.npz', allow_pickle=True)
data_2019 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2019.npz', allow_pickle=True)
data_2020 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2020.npz', allow_pickle=True)

# %%
# Extract and combine the data from each of the files
date_time = np.concatenate((data_2015['date_time'], data_2016['date_time'], data_2017['date_time'], data_2018['date_time'], data_2019['date_time'], data_2020['date_time']))
obs_species = np.concatenate((data_2015['obs_species'], data_2016['obs_species'], data_2017['obs_species'], data_2018['obs_species'], data_2019['obs_species'], data_2020['obs_species']))
obs_tilenum = np.concatenate((data_2015['obs_tilenum'], data_2016['obs_tilenum'], data_2017['obs_tilenum'], data_2018['obs_tilenum'], data_2019['obs_tilenum'], data_2020['obs_tilenum']))
obs_lon = np.concatenate((data_2015['obs_lon'], data_2016['obs_lon'], data_2017['obs_lon'], data_2018['obs_lon'], data_2019['obs_lon'], data_2020['obs_lon']))
obs_lat = np.concatenate((data_2015['obs_lat'], data_2016['obs_lat'], data_2017['obs_lat'], data_2018['obs_lat'], data_2019['obs_lat'], data_2020['obs_lat']))
obs_obs = np.concatenate((data_2015['obs_obs'], data_2016['obs_obs'], data_2017['obs_obs'], data_2018['obs_obs'], data_2019['obs_obs'], data_2020['obs_obs']))
obs_fcst = np.concatenate((data_2015['obs_fcst'], data_2016['obs_fcst'], data_2017['obs_fcst'], data_2018['obs_fcst'], data_2019['obs_fcst'], data_2020['obs_fcst']))
obs_ana = np.concatenate((data_2015['obs_ana'], data_2016['obs_ana'], data_2017['obs_ana'], data_2018['obs_ana'], data_2019['obs_ana'], data_2020['obs_ana']))

# %%
#data_2015 = np.load(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_extend_datetime_2015.npz', allow_pickle=True)

## Extract and combine the data from each of the files
#date_time = ((data_2015['date_time']))
#obs_species = ((data_2015['obs_species']))
#obs_tilenum = ((data_2015['obs_tilenum']))
#obs_lon = ((data_2015['obs_lon']))
#obs_lat = ((data_2015['obs_lat']))
#obs_obs = ((data_2015['obs_obs']))
#obs_fcst = ((data_2015['obs_fcst']))
#obs_ana = ((data_2015['obs_ana']))

# %%
# Calculate obs minus fcst
obs_minus_fcst = []
obs_minus_ana = []
for i in range(len(obs_obs)):
    obs_minus_fcst_chunk = obs_obs[i] - obs_fcst[i]
    obs_minus_fcst.append(obs_minus_fcst_chunk)
    obs_minus_ana_chunk = obs_obs[i] - obs_ana[i]
    obs_minus_ana.append(obs_minus_ana_chunk)

# %%
# Calculate obs minus ana
# obs_minus_ana = []
# for i in range(len(obs_obs)):
#     obs_minus_ana_chunk = obs_obs[i] - obs_ana[i]
#     obs_minus_ana.append(obs_minus_ana_chunk)

# %%
# Convert the lists to numpy arrays
obs_minus_fcst = np.array(obs_minus_fcst)
obs_minus_ana = np.array(obs_minus_ana)

# %%
# Find unique tilenum values
unique_tilenum = np.unique(obs_tilenum)

# Find the number of unique tilenum values
num_unique_tilenum = len(unique_tilenum)

# Print the number of unique tilenum values
print(f"Number of unique tilenum values: {num_unique_tilenum}")
# Out:
# Number of unique tilenum values: 96049

# %%
# Sort the arrays based on obs_tilenum
sort_indices = np.argsort(obs_tilenum)
sorted_obs_tilenum = obs_tilenum[sort_indices]
sorted_obs_species = obs_species[sort_indices]
sorted_obs_obs = obs_obs[sort_indices]
sorted_obs_fcst = obs_fcst[sort_indices]
sorted_obs_ana = obs_ana[sort_indices]
sorted_obs_minus_fcst = obs_minus_fcst[sort_indices]
sorted_obs_minus_ana = obs_minus_ana[sort_indices]
sorted_date_time = date_time[sort_indices]

# Find the unique tilenum values and their counts
unique_tilenum, counts = np.unique(sorted_obs_tilenum, return_counts=True)

# Calculate the indices where the groups should be split
split_indices = np.cumsum(counts)[:-1]

# Split the sorted arrays based on the split indices
obs_species_grouped = np.split(sorted_obs_species, split_indices)
obs_obs_grouped = np.split(sorted_obs_obs, split_indices)
obs_fcst_grouped = np.split(sorted_obs_fcst, split_indices)
obs_ana_grouped = np.split(sorted_obs_ana, split_indices)
obs_minus_fcst_grouped = np.split(sorted_obs_minus_fcst, split_indices)
obs_minus_ana_grouped = np.split(sorted_obs_minus_ana, split_indices)
date_time_grouped = np.split(sorted_date_time, split_indices)

# %%
# Print the length of obs_obs_grouped
print(f"Length of obs_obs_grouped: {len(obs_obs_grouped)}")
# Out:
# Length of obs_obs_grouped: 96049

# %%
# Run this cell if you have a multi-sensor experiment

# Find the number of observations for each tilenum
num_obs_smap = []
num_obs_ascat = []
num_obs_smap_cm = []
num_obs_ascat_cm = []
for i in range(num_unique_tilenum):
    num_obs_smap.append(len(obs_obs_grouped[i][obs_species_grouped[i] < 5]))
    num_obs_ascat.append(len(obs_obs_grouped[i][obs_species_grouped[i] > 4]))
    # We need to cross mask the observations to get the observations if obs_obs_grouped[i] contains both SMAP and ASCAT observations
    if len(obs_obs_grouped[i][obs_species_grouped[i] < 5]) > 0 and len(obs_obs_grouped[i][obs_species_grouped[i] > 4]) > 0:
        num_obs_smap_cm.append(len(obs_obs_grouped[i][obs_species_grouped[i] < 5]))
        num_obs_ascat_cm.append(len(obs_obs_grouped[i][obs_species_grouped[i] > 4]))
    else:
        num_obs_smap_cm.append(0)
        num_obs_ascat_cm.append(0)
        
#Calculate the mean of the observations for each tilenum
mean_obs_smap = []
mean_obs_ascat = []
for i in range(num_unique_tilenum):
    mean_obs_smap.append(np.mean(obs_obs_grouped[i][obs_species_grouped[i] < 5]))
    mean_obs_ascat.append(np.mean(obs_obs_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the mean of the forecasts for each tilenum
mean_fcst_smap = []
mean_fcst_ascat = []
for i in range(num_unique_tilenum):
    mean_fcst_smap.append(np.mean(obs_fcst_grouped[i][obs_species_grouped[i] < 5]))
    mean_fcst_ascat.append(np.mean(obs_fcst_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the mean of the analyses for each tilenum
mean_ana_smap = []
mean_ana_ascat = []
for i in range(num_unique_tilenum):
    mean_ana_smap.append(np.mean(obs_ana_grouped[i][obs_species_grouped[i] < 5]))
    mean_ana_ascat.append(np.mean(obs_ana_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the mean of the obs minus fcst for each tilenum
mean_obs_minus_fcst_smap = []
mean_obs_minus_fcst_ascat = []
for i in range(num_unique_tilenum):
    mean_obs_minus_fcst_smap.append(np.mean(obs_minus_fcst_grouped[i][obs_species_grouped[i] < 5]))
    mean_obs_minus_fcst_ascat.append(np.mean(obs_minus_fcst_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the mean of the obs minus ana for each tilenum
mean_obs_minus_ana_smap = []
mean_obs_minus_ana_ascat = []
for i in range(num_unique_tilenum):
    mean_obs_minus_ana_smap.append(np.mean(obs_minus_ana_grouped[i][obs_species_grouped[i] < 5]))
    mean_obs_minus_ana_ascat.append(np.mean(obs_minus_ana_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the standard deviation of the obs_minus_fcst for each tilenum
std_obs_minus_fcst_smap = []
std_obs_minus_fcst_ascat = []
for i in range(num_unique_tilenum):
    std_obs_minus_fcst_smap.append(np.std(obs_minus_fcst_grouped[i][obs_species_grouped[i] < 5]))
    std_obs_minus_fcst_ascat.append(np.std(obs_minus_fcst_grouped[i][obs_species_grouped[i] > 4]))

# Calculate the standard deviation of the obs_minus_ana for each tilenum
std_obs_minus_ana_smap = []
std_obs_minus_ana_ascat = []
for i in range(num_unique_tilenum):
    std_obs_minus_ana_smap.append(np.std(obs_minus_ana_grouped[i][obs_species_grouped[i] < 5]))
    std_obs_minus_ana_ascat.append(np.std(obs_minus_ana_grouped[i][obs_species_grouped[i] > 4]))
    
# Find the number of observations of each species for each tilenum
num_obs_s1 = []
num_obs_s2 = []
num_obs_s3 = []
num_obs_s4 = []
num_obs_s5 = []
num_obs_s6 = []
num_obs_s7 = []

for i in range(num_unique_tilenum):
    num_obs_s1.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 1]))
    num_obs_s2.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 2]))
    num_obs_s3.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 3]))
    num_obs_s4.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 4]))
    num_obs_s5.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 5]))
    num_obs_s6.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 6]))
    num_obs_s7.append(len(obs_obs_grouped[i][obs_species_grouped[i] == 7]))
# Out:
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /home/amfox/.conda/envs/diag/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
print(date_time_grouped[i])
# Out:
# [{'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([228], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([184], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([182], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([225], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([17], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([261], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([174], dtype=int32), 'pentad': array([35], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([253], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([22], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([266], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([10], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([288], dtype=int32), 'pentad': array([58], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([196], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([5], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([217], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([166], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([244], dtype=int32), 'pentad': array([49], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([168], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([24], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([206], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([25], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([177], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([225], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([240], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([223], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([204], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([236], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([214], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([10], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([276], dtype=int32), 'pentad': array([56], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([180], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([262], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([207], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([209], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([168], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([263], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([247], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([224], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([218], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([25], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([206], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([219], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([204], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([10], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([286], dtype=int32), 'pentad': array([58], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([227], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([224], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([201], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([168], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([31], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([212], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([30], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([273], dtype=int32), 'pentad': array([55], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([195], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([200], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([21], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([203], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([189], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([9], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([262], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([9], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([29], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([211], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([158], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([229], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([255], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([170], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([204], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([254], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([185], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([167], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([160], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([205], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([226], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([10], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([286], dtype=int32), 'pentad': array([58], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([6], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([160], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([17], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([229], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([10], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([275], dtype=int32), 'pentad': array([55], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([175], dtype=int32), 'pentad': array([35], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([17], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([169], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([9], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([250], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([29], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([180], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([228], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([251], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([251], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([208], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([159], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([239], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([18], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([199], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([182], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([235], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([167], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([10], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([279], dtype=int32), 'pentad': array([56], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([190], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([161], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([209], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([250], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([220], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([170], dtype=int32), 'pentad': array([34], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([201], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([27], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([179], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([31], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([213], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([189], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([30], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([181], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([221], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([200], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([25], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([207], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([238], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([6], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([171], dtype=int32), 'pentad': array([35], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([27], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([239], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([21], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([265], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([225], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([201], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([29], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([211], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([189], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([251], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([232], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([197], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([30], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([181], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([196], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([245], dtype=int32), 'pentad': array([49], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([226], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([195], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([178], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([188], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([163], dtype=int32), 'pentad': array([33], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([31], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([212], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([160], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([186], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([227], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([201], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([267], dtype=int32), 'pentad': array([54], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([195], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([200], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([189], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([166], dtype=int32), 'pentad': array([33], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([177], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([189], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([224], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([193], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([24], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([206], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([218], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([24], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([237], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([21], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([233], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([188], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([240], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([31], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([213], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([223], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([18], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([199], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([214], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([240], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([247], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([21], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([265], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([207], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([231], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([6], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([161], dtype=int32), 'pentad': array([33], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([216], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([7], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([187], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([185], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([245], dtype=int32), 'pentad': array([49], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([232], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([23], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([204], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([263], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([195], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([26], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([269], dtype=int32), 'pentad': array([54], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([22], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([203], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([216], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([9], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([262], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([200], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([215], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([252], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([224], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([216], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([248], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([197], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([219], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([9], dtype=int32), 'day': array([5], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([248], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([22], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([204], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([223], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([6], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([165], dtype=int32), 'pentad': array([33], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([27], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([239], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([221], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([5], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([186], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([225], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([30], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([211], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([185], dtype=int32), 'pentad': array([37], dtype=int32)}
# ...
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([222], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([22], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([203], dtype=int32), 'pentad': array([41], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([193], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([218], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([18], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([230], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([245], dtype=int32), 'pentad': array([49], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([252], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([6], dtype=int32), 'day': array([27], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([178], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([7], dtype=int32), 'day': array([25], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([207], dtype=int32), 'pentad': array([42], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([223], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([216], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([10], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([275], dtype=int32), 'pentad': array([55], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([226], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([19], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([201], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([257], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([158], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([193], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([10], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([287], dtype=int32), 'pentad': array([58], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([217], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([228], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([12], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([256], dtype=int32), 'pentad': array([51], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([221], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([30], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([242], dtype=int32), 'pentad': array([49], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([228], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([8], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([190], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([18], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([231], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([2], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([215], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([8], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([232], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([8], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([227], dtype=int32), 'pentad': array([46], dtype=int32)}
#  {'year': array([2019], dtype=int32), 'month': array([9], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([3], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([184], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([1], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([182], dtype=int32), 'pentad': array([37], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([171], dtype=int32), 'pentad': array([35], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([13], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([225], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([233], dtype=int32), 'pentad': array([47], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([158], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([7], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([159], dtype=int32), 'pentad': array([32], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([7], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([195], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([11], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([224], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([192], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([6], dtype=int32), 'day': array([27], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([179], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([171], dtype=int32), 'pentad': array([35], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([8], dtype=int32), 'day': array([5], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([217], dtype=int32), 'pentad': array([44], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([8], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([223], dtype=int32), 'pentad': array([45], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([7], dtype=int32), 'day': array([9], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([191], dtype=int32), 'pentad': array([38], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([8], dtype=int32), 'day': array([24], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([237], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([6], dtype=int32), 'day': array([29], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([180], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([7], dtype=int32), 'day': array([15], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([196], dtype=int32), 'pentad': array([40], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([9], dtype=int32), 'day': array([4], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([247], dtype=int32), 'pentad': array([50], dtype=int32)}
#  {'year': array([2016], dtype=int32), 'month': array([9], dtype=int32), 'day': array([20], dtype=int32), 'hour': array([6], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([264], dtype=int32), 'pentad': array([53], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([31], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([212], dtype=int32), 'pentad': array([43], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([10], dtype=int32), 'day': array([16], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([289], dtype=int32), 'pentad': array([58], dtype=int32)}
#  {'year': array([2015], dtype=int32), 'month': array([6], dtype=int32), 'day': array([29], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([180], dtype=int32), 'pentad': array([36], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([28], dtype=int32), 'hour': array([3], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([240], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2018], dtype=int32), 'month': array([7], dtype=int32), 'day': array([10], dtype=int32), 'hour': array([0], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([191], dtype=int32), 'pentad': array([39], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([14], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([258], dtype=int32), 'pentad': array([52], dtype=int32)}
#  {'year': array([2017], dtype=int32), 'month': array([8], dtype=int32), 'day': array([25], dtype=int32), 'hour': array([21], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([237], dtype=int32), 'pentad': array([48], dtype=int32)}
#  {'year': array([2020], dtype=int32), 'month': array([9], dtype=int32), 'day': array([6], dtype=int32), 'hour': array([9], dtype=int32), 'min': array([0], dtype=int32), 'sec': array([0], dtype=int32), 'dofyr': array([250], dtype=int32), 'pentad': array([50], dtype=int32)}]

# %%
# Count the number of overlapping ASCAT and SMAP observations which have to have the same date_time
num_obs_smap_ascat = []

for i in range(num_unique_tilenum):
    # if i is divisible by 1000 print the progress
    if i % 1000 == 0:
        print(i)
    smap_times = (date_time_grouped[i][obs_species_grouped[i] < 5])
    ascat_times = (date_time_grouped[i][obs_species_grouped[i] > 4])
    # Convert dictionaries to tuples
    smap_times_tuples = [tuple((k, int(v[0]) if isinstance(v, np.ndarray) else v) for k, v in sorted(item.items())) for item in smap_times]
    ascat_times_tuples = [tuple((k, int(v[0]) if isinstance(v, np.ndarray) else v) for k, v in sorted(item.items())) for item in ascat_times]

    # Perform set operations
    num_obs_smap_ascat.append(len(set(smap_times_tuples).intersection(ascat_times_tuples)))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000

# %%
# Assign lon and lat to each tilenum
lon_tilenum = []
lat_tilenum = []
for i in range(num_unique_tilenum):
    lon_tilenum.append(lon[int(unique_tilenum[i])])
    lat_tilenum.append(lat[int(unique_tilenum[i])])

# Convert the lists to numpy arrays
lon_tilenum = np.array(lon_tilenum)
lat_tilenum = np.array(lat_tilenum)

# %%
# Run this cell if you have a multi-sensor experiment
# Save all the calculated values to a file
np.savez(f'{expt_name}_{start_date_str}_{end_date_str}_obsfcstana_stats.npz',
         unique_tilenum=unique_tilenum,
         num_obs_smap=num_obs_smap,
         num_obs_ascat=num_obs_ascat,
         num_obs_smap_cm=num_obs_smap_cm,
         num_obs_ascat_cm=num_obs_ascat_cm,
         num_obs_s1=num_obs_s1,
         num_obs_s2=num_obs_s2,
         num_obs_s3=num_obs_s3,
         num_obs_s4=num_obs_s4,
         num_obs_s5=num_obs_s5,
         num_obs_s6=num_obs_s6,
         num_obs_s7=num_obs_s7,
         num_obs_smap_ascat=num_obs_smap_ascat,
         mean_obs_smap=mean_obs_smap,
         mean_obs_ascat=mean_obs_ascat,
         mean_fcst_smap=mean_fcst_smap,
         mean_fcst_ascat=mean_fcst_ascat,
         mean_ana_smap=mean_ana_smap,
         mean_ana_ascat=mean_ana_ascat,
         mean_obs_minus_fcst_smap=mean_obs_minus_fcst_smap,
         mean_obs_minus_fcst_ascat=mean_obs_minus_fcst_ascat,
         mean_obs_minus_ana_smap=mean_obs_minus_ana_smap,
         mean_obs_minus_ana_ascat=mean_obs_minus_ana_ascat,
         std_obs_minus_fcst_smap=std_obs_minus_fcst_smap,
         std_obs_minus_fcst_ascat=std_obs_minus_fcst_ascat,
         std_obs_minus_ana_smap=std_obs_minus_ana_smap,
         std_obs_minus_ana_ascat=std_obs_minus_ana_ascat,
         lon_tilenum=lon_tilenum,
         lat_tilenum=lat_tilenum)

# %%
test_array = num_obs_smap_ascat
test_array = np.array(test_array)
#test_array[test_array < 1] = -999
    
obarray = np.empty([num_unique_tilenum, 3])
obarray[:, 1] = lon_tilenum
obarray[:, 2] = lat_tilenum
obarray[:, 0] = test_array
   
plot_global(obarray,False,'Number of ASCAT Obs Assimilated','Total')

# %%
obarray[:, 0] = num_obs_smap_cm
   
plot_global(obarray,False,'num_obs_smap_cm','Total')

# %%
obarray[:, 0] = num_obs_smap
   
plot_global(obarray,False,'num_obs_smap','Total')
