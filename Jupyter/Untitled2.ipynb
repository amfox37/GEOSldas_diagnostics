# %%
import os

# Define the top-level directory to search
path = '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg'

# Define the file name and extension to look for
file_name = 'ASCAT_M36.ens_avg.ldas_ObsFcstAna'
file_ext = '.bin'

# Use os.walk to recursively traverse all directories and subdirectories under the top-level directory
files = [os.path.join(root, file) for root, dirs, files in os.walk(path) for file in files if file.startswith(file_name) and file.endswith(file_ext)]

# Print the list of files that match the criteria
print(files)
# Out:
# ['/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190802_1800z.bin', '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190811_0000z.bin', '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190811_0900z.bin', '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190821_0900z.bin', '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190806_0600z.bin', '/discover/nobackup/amfox/Experiments/ASCAT_test/ASCAT_M36/output/SMAP_EASEv2_M36_GLOBAL/ana/ens_avg/Y2019/M08/ASCAT_M36.ens_avg.ldas_ObsFcstAna.20190828_1500z.bin', '
# ...
